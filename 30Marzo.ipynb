# %%
import pandas as pd

df = pd.read_excel("FilesDS/bancolen.xlsx")

# %%
df.head()
# Out:
#    CÓDIGO      SEXO   SUELDO  EDAD NIVEL EDUCACIONAL ESTADO CIVIL  OFICINA  \
# 0       1  M         1200000  39.0          TEC          CAS            42
# 1       2  M         1200000  55.0          TEC          CAS            16
# 2       3  M          800000  47.0          UNV          CAS            48
# 3       4  F          700000  47.0          TEC          CAS            79
# 4       5  F         4730000  32.0          TEC          CAS            52
#
#   CODIGO COMUNA            CIUDAD  DEPÓSITOS MES1  DEPÓSITOS MES2  \
# 0            31  COQUIMBO                 3788129          512102
# 1            90  SANTIAGO                       0               0
# 2            87  SANTIAGO                       0          800000
# 3           148  SAN FERNANDO             1112326          104780
# 4            88  SANTIAGO                       0          750000
#
#    DEPÓSITOS MES3  DEUDA ACTUAL  DEUDA MES ANTERIOR  PROMEDIO DEUDA  \
# ...

# %%
df.tail()
# Out:
#       CÓDIGO      SEXO   SUELDO  EDAD NIVEL EDUCACIONAL ESTADO CIVIL  OFICINA  \
# 2289    2290  M           75000  40.0          UNV          CAS            35
# 2290    2291  F          600000  49.0          MED          CAS            62
# 2291    2292  M         2000000  40.0          UNV          SEP           128
# 2292    2293  F         5000000  37.0          TEC          SOL            73
# 2293    2294  M         5000000  42.0          MED          CAS            55
#
#      CODIGO COMUNA            CIUDAD  DEPÓSITOS MES1  DEPÓSITOS MES2  \
# 2289            84  SANTIAGO                       0          570775
# 2290           292  PUERTO VARAS                   0               0
# 2291            88  SANTIAGO                       0          307335
# 2292            86  SANTIAGO                       0          430700
# 2293            90  SANTIAGO                       0          125658
#
#       DEPÓSITOS MES3  DEUDA ACTUAL  DEUDA MES ANTERIOR  PROMEDIO DEUDA  \
# ...

# %%
df.describe()
# Out:
#             CÓDIGO        SUELDO         EDAD      OFICINA  DEPÓSITOS MES1  \
# count  2294.000000  2.294000e+03  2289.000000  2294.000000    2.294000e+03
# mean   1147.500000  1.714922e+06    43.561381    68.542720    3.102876e+05
# std     662.365081  2.213844e+06     7.985992    40.164768    8.823218e+05
# min       1.000000  4.350000e+04    23.000000     0.000000    0.000000e+00
# 25%     574.250000  5.000000e+05    39.000000    31.000000    0.000000e+00
# 50%    1147.500000  8.000000e+05    44.000000    56.000000    0.000000e+00
# 75%    1720.750000  1.600750e+06    50.000000    92.000000    0.000000e+00
# max    2294.000000  9.940000e+06    64.000000   155.000000    1.022472e+07
#
#        DEPÓSITOS MES2  DEPÓSITOS MES3  DEUDA ACTUAL  DEUDA MES ANTERIOR  \
# count    2.294000e+03    2.277000e+03   2294.000000         2294.000000
# mean     5.325353e+05    2.223975e+05   1127.667393         7008.370968
# std      6.426396e+05    1.836820e+06   1842.400137        15131.036407
# ...

# %%
LIST = df[df.SUELDO>=2000000]
LIST
# Out:
#       CÓDIGO      SEXO   SUELDO  EDAD NIVEL EDUCACIONAL ESTADO CIVIL  OFICINA  \
# 4          5  F         4730000  32.0          TEC          CAS            52
# 8          9  M         7350000  41.0          UNV          CAS            55
# 10        11  M         2279000  40.0          UNV          SEP           138
# 29        30  F         6250000  36.0          MED          SOL            90
# 31        32  M         2349000  53.0          TEC          CAS            84
# ...      ...       ...      ...   ...               ...          ...      ...
# 2273    2274  F         6500000  35.0          TEC          VIU            21
# 2274    2275  F         5000000  33.0          TEC          VIU            62
# 2291    2292  M         2000000  40.0          UNV          SEP           128
# 2292    2293  F         5000000  37.0          TEC          SOL            73
# 2293    2294  M         5000000  42.0          MED          CAS            55
#
# ...
